# %%
# %%bq query
# #SQL query to return all from nyc-tlc
# SELECT *
# FROM `nyc-tlc.green.trips_2014`
# Out:
# QueryResultsTable job_k_4S19qs5GWbfGAIDiXzVWtLSuUJ

# %%
#made some changes here to make sure it works
